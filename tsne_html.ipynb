# %%
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd
from plotly.subplots import make_subplots
import pandas as pd
import time
from sklearn.manifold import TSNE, Isomap, LocallyLinearEmbedding, SpectralEmbedding

import plotly_express as px
import plotly.graph_objs as go
import ipywidgets as widgets
import os
from sklearn import preprocessing

# %%
min_max_scaler = preprocessing.MinMaxScaler()
df=pd.read_csv("./csvs/feat_frequency_bins.csv",error_bad_lines=False)
# ['noise','piano','guitar',"voc"]
not_want=['noise','piano','guitar',"voc","5_stack"]
df=df[~df.label.isin(not_want)].reset_index()
# df=df.drop(['zc','sc'],axis=1)
n_neighbors = 10
X =df.loc[:, ~df.columns.isin(['label','path'])].values

X = np.nan_to_num(X)
time_start = time.time()
tsne = TSNE(n_components=2, random_state=0, perplexity=20, verbose=1)
# tsne = Isomap(n_neighbors, n_components=2)
# tsne = LocallyLinearEmbedding(n_neighbors,n_components=4)
# tsne = SpectralEmbedding(n_neighbors=16,n_components=5,random_state=1)
X_2d = tsne.fit_transform(X)

df2=pd.concat([df["path"],df["label"],pd.Series(X_2d[:,0]),pd.Series(X_2d[:,1])],axis=1)
df2.columns=["path","label","v1","v2"]
# Out:
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 737 samples in 0.005s...
# [t-SNE] Computed neighbors for 737 samples in 0.041s...
# [t-SNE] Computed conditional probabilities for sample 737 / 737
# [t-SNE] Mean sigma: 6194.375836
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 63.765453
# [t-SNE] KL divergence after 1000 iterations: 0.559905

# %%
p = px.scatter(df2, x="v1",
                 y="v2",color="label",hover_data=["path"],color_discrete_sequence=px.colors.qualitative.Dark24)
for trace in p.data:
    trace.update(hoverinfo="none",hovertemplate= '')

def hover_fn(trace, points, state):
    if points.point_inds:
        ind = points.point_inds[0]
        drmName=trace.customdata[ind][0][2:]
        filename=os.getcwd()+drmName
        os.system("play %s trim 0 0.5 &" % filename)
        hover_data.value = str(drmName)
        
hover_data = widgets.Textarea()  
layout = go.Layout(hovermode=False)
fig  = go.FigureWidget(p)
for f in fig.data:
    f.on_hover(hover_fn)

display(fig,widgets.HBox([hover_data]))
# Out:
# FigureWidget({
#     'data': [{'customdata': array([['../dk_data/hat/Kit_10_Hat02.wav'],
#                        …
# HBox(children=(Textarea(value=''),))

# %%
df
# Out:
#     index         freq0         freq1         freq2         freq3  \
# 0       1  2.789445e+04  5.247060e+04  8.100084e+04  1.412311e+05
# 1       2  6.019918e+05  3.550987e+04  1.773464e+04  1.198439e+04
# 2       3  2.178977e+04  3.023752e+04  3.699901e+04  7.232523e+04
# 3       5  2.130992e+06  9.017397e+05  4.479310e+05  3.230957e+05
# 4       6  2.669362e+04  2.480331e+04  4.965264e+04  5.616889e+04
# ..    ...           ...           ...           ...           ...
# 63     94  2.281218e+06  1.725564e+06  6.108738e+05  3.452914e+05
# 64     95  3.861270e+06  1.653622e+06  7.000386e+05  4.248954e+05
# 65     97  8.697154e+04  9.980714e+04  1.521523e+05  6.024796e+06
# 66     98  3.218227e+06  5.522071e+06  4.461838e+06  1.511984e+06
# 67     99  1.194218e+06  2.227203e+05  1.819704e+05  1.628011e+05
#
#            freq4          freq5          freq6          freq7          freq8  \
# 0   1.260010e+05   64243.891879   28140.786417   16666.332404   13742.178322
# 1   9.188707e+03    7646.571771    6711.468957    6082.418580    5706.105315
# 2   1.083068e+05  123334.624795  107133.203212  121871.790678  122707.609628
# 3   2.813268e+05  234974.241525  137891.606526  111050.350310  100665.313526
# 4   4.032179e+04   37957.385088   28611.611197   20233.810025   11353.778083
# ..           ...            ...            ...            ...            ...
# 63  2.562265e+05  209486.520550  182415.448559  164470.012287  153136.417734
# 64  3.039446e+05  251499.689087  220854.300623  196708.706161  181906.105125
# 65  1.610493e+06  196945.046483  110700.385657   80593.713614   66222.880219
# 66  9.733973e+05  745289.819708  622621.335235  550183.999875  506857.479373
# 67  1.063510e+05   81416.228109   55383.877299   32628.676663   25085.073416
#
#     ...            zc        sc        l  env_shape0  env_shape1  env_shape2  \
# 0   ...   6843.317350 -1.651207   9760.0 -432.897968  166.747772   -8.264308
# 1   ...    858.345972 -3.411944  28296.0   12.581790  -21.833822   13.394493
# 2   ...  12540.426871 -1.103590   8450.0  500.291527 -280.856071   62.423719
# 3   ...      0.000000 -4.605170  41000.0   -4.976976   12.676324  -11.043110
# 4   ...   8352.253677 -1.590586  32688.0    2.087279   -3.996229    2.663717
# ..  ...           ...       ...      ...         ...         ...         ...
# 63  ...   1414.537463 -3.474445  41000.0   -1.769667    4.120618   -2.565919
# 64  ...   5240.775821 -4.423015  56646.0   -4.208066   11.484558   -9.906527
# 65  ...      0.000000 -4.605170  41000.0   -2.127299    6.418371   -7.887583
# 66  ...      0.000000 -4.605170  41000.0  -13.103633   26.044684  -17.432143
# 67  ...   5618.876027 -2.631950  34759.0    1.567384   -3.238756    2.568128
#
#     env_shape3  env_shape4    label  \
# 0    -2.679820    0.235227      hat
# 1    -3.407859    0.301453      tom
# 2    -6.866204    0.326203      hat
# 3     3.452142   -0.121439  3_stack
# 4    -0.723206    0.067856      hat
# ..         ...         ...      ...
# 63   -0.164572    0.382418  3_stack
# 64    2.922220   -0.089973      hat
# 65    3.708858   -0.128791  3_stack
# 66    4.472610    0.056800  3_stack
# 67   -1.051792    0.214354  tom_low
#
#                                                  path
# 0                     ../dk_data/hat/Kit_10_Hat02.wav
# 1              ../dk_data/tom/CYCdh_ElecK03-Tom02.wav
# 2             ../dk_data/hat/Nu-Disco_ClosedHat15.wav
# 3                         ../dk_data/3_stack/1841.wav
# 4             ../dk_data/hat/CYCdh_Kurz06-HfHat01.wav
# ..                                                ...
# 63                        ../dk_data/3_stack/1636.wav
# 64                 ../dk_data/hat/Thats_incorrect.wav
# 65                         ../dk_data/3_stack/116.wav
# 66                        ../dk_data/3_stack/1888.wav
# 67  ../dk_data/tom_low/Roland_JD-990-MaxV_-_RIM-TO...
#
# [68 rows x 31 columns]

# %%
/dk_data/kick/Jomox_Xbase-09-LongBD01.wav
/dk_data/kick/Jomox_Xbase-09-LongBD01.wav
/dk_data/kick/Roland_TR-909_BD_Selection-KK-Di909BD_59.wav
