# %%
from pippi.oscs import Osc, Osc2d, Pulsar, Pulsar2d, Alias, Bar
from pippi import dsp, interpolation, wavetables, fx, oscs,soundpipe
from pippi.soundbuffer import SoundBuffer
from pippi.wavesets import Waveset
from pippi import dsp, fx
import random
import sounddevice as sd
from IPython.display import Audio
import librosa as lib
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
from pippi import dsp, noise
import scipy
import param_generation as pg
from helpers import *
# %load_ext autoreload
# %autoreload 2
sr=44100
plt.figure(figsize=(8, 5))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
high = noise.bln('sine',1,30, 150000,channels=1)
high.frames = butter_bandpass_filter(high.frames, 9999,10800, sr, order=1)
specShow(high)
sd.play(high,blocking=True)

# %%
p=pg.SynthParams()

high = noise.bln('sine',1,30, 150000,channels=1)
high.frames = butter_bandpass_filter(high.frames, 9999,10800, sr, order=1)
specShow(high)
sd.play(high,blocking=True)
