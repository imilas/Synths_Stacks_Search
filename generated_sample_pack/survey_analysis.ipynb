# %%
import pandas as pd
import numpy as np

df=pd.read_csv("model_predictions.csv",header=None)
df.columns=["name","fc","fc_cat","cnn_cat","env_and_freq_cat","average_cat","stack_size","iteration_num"]
df=df.sample(frac=1)

# %%
#how often does a stacksize result in a generation?
df.groupby('stack_size').count()
# Out:
#             name    fc  fc_cat  cnn_cat  env_and_freq_cat  average_cat  \
# stack_size
# 1           1781  1781    1781     1781              1781         1781
# 2           1753  1753    1753     1753              1753         1753
# 4            316   316     316      316               316          316
#
#             iteration_num
# stack_size
# 1                    1781
# 2                    1753
# 4                     316

# %%
#what are the group counts?
df=df[df["average_cat"]==df["cnn_cat"]]
df.groupby('average_cat').count()
# Out:
#              name    fc  fc_cat  cnn_cat  env_and_freq_cat  stack_size  \
# average_cat
# clap          150   150     150      150               150         150
# hat          1027  1027    1027     1027              1027        1027
# kick          801   801     801      801               801         801
# rim           327   327     327      327               327         327
# snare         891   891     891      891               891         891
#
#              iteration_num
# average_cat
# clap                   150
# hat                   1027
# kick                   801
# rim                    327
# snare                  891

# %%
df1=df[df["stack_size"]==1]
df2=df[df["stack_size"]==2]
df4=df[df["stack_size"]==4]

# %%
survey_rows=pd.concat([df1.groupby('cnn_cat').head(20),df2.groupby('cnn_cat').head(20),df4.groupby('cnn_cat').head(20)])
survey_rows
# Out:
#             name        fc fc_cat cnn_cat env_and_freq_cat average_cat  \
# 3629  1-2P0O.wav  0.916376    hat     hat              hat         hat
# 151   1-MMM0.wav  0.864433   kick    kick              hat        kick
# 1317  1-3A5S.wav  0.915831   kick    kick              hat        kick
# 3795  1-KZAA.wav  0.853264   kick    kick            snare        kick
# 3174  1-PTNF.wav  0.876694   kick    kick            snare        kick
# ...          ...       ...    ...     ...              ...         ...
# 579   4-OURV.wav  0.908681  snare    clap             clap        clap
# 1623  4-9HGN.wav  0.984712  snare     rim              hat         rim
# 3230  4-DNBQ.wav  0.942446  snare     rim              hat         rim
# 916   4-ITB7.wav  0.923348  snare     rim              hat         rim
# 3313  4-9D47.wav  0.724753  snare    clap              hat        clap
#
#       stack_size  iteration_num
# 3629           1          81583
# 151            1          37705
# 1317           1           8066
# 3795           1          86252
# 3174           1          66464
# ...          ...            ...
# 579            4             27
# 1623           4          17667
# 3230           4          68562
# 916            4           6799
# 3313           4          71416
#
# [284 rows x 8 columns]

# %%
from shutil import copyfile

for n in survey_rows["name"]:
    copyfile("survey/"+n, "./filtered_survey/"+n)

sr=survey_rows.sort_values('name', ascending=True)
sr.to_csv("survey_answers.csv",index=False)

# %%
surv=survey_rows[["name"]].copy()
surv=surv.sort_values('name', ascending=True)
surv=surv.reset_index(drop=True)
surv["drum_category"]=""
surv.to_csv("survey.csv",index=False)
